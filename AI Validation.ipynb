# %% [markdown]
# <a href="https://colab.research.google.com/github/selemansolar-ai/Unshakable_Energy_AI/blob/main/AI%20Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplot.pyplot as plt

# 1.CHORA GRAPH YA ULINGANISHO
plplt.figure(figsize=(12,6))

# Msatari wa 1:Power halisi kutka sensor
plt.plot(df_halisi['saa'], df_halisi['Power_W'],
        labe='Power_Halisi',
        marker='o',
        color='orange',
         linestyle='--',
         linewidth=3)

# Mstari wa 2:Power Utabiri- BLUE DOTTED
plt.plot(df_halisi['saa'], df_halisi['Power_utab;iri_W'],
         label='Power Utabiri wa AI',
         marker='x',
         color='blue',
         linestyle='--',
         linewidth=2)

# 2. TITLE AND LABLES
plt.title('ULINGANISHO: AI SENSOR - SOLAR POWER MWANZA,fontsize=16, fontweight='bold)
plt.xlabel('saa ya siku', fontsize=12)
plt.ylabel('Power (Watts)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.lengend()
plt.xtick(df_halisi['saa'])

plt.show()
print("✅ GRAPH IMEMALIZIKA!")
